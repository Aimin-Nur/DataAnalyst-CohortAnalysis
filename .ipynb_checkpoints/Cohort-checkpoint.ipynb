# %% [markdown]
# # Cohort Analysis
#
# Sebuah project Data Analayst untuk mengetahui bagaimana pola pembelian pelanggan dalam periode waktu tertentu (Cohort Analysis).
#
# Acquisition Cohort Analysis adalah jenis cohort analysis yang akan digunakan dalam project analisis kali ini, yang dimana saya akan mengambil insight Cohort Analysis berdasarkan tanggal atau waktu customer pertama kali melakukan transaksi dan kapan terakhir kali customer melakukan transaksi di platform e-commerce.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv', engine='python', encoding = 'ISO8859-1' )
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Reformat Timestamp

# %%
import dateutil
from datetime import datetime as dt
from pytz import utc

# %%
df['Datetime'] = df['InvoiceDate'].apply(lambda x : dateutil.parser.parse(x).timestamp())
df['Month'] = df['Datetime'].apply(lambda x : dt.fromtimestamp(x,utc).month)
df['Year'] = df['Month'].apply(lambda x : dt.fromtimestamp(x,utc).year)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# InvoiceNo                 0
# StockCode                 0
# Description            1454
# Quantity                  0
# InvoiceDate               0
# UnitPrice                 0
# CustomerID           135037
# Country                   0
# Datetime                  0
# Month                     0
# Year                      0
# cohort                    0
# transaksi_pertama    135037
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# InvoiceNo            0
# StockCode            0
# Description          0
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID           0
# Country              0
# Datetime             0
# Month                0
# Year                 0
# cohort               0
# transaksi_pertama    0
# dtype: int64

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country      Datetime  Month  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  1.291163e+09     12
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  1.291163e+09     12
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
#
#    Year
# 0  1970
# 1  1970
# 2  1970
# 3  1970
# 4  1970

# %% [markdown]
# ### Cohort

# %%
df['cohort'] = df.apply(lambda row : (row['Year']*100)+(row['Month']), axis=1)
cohorts = df.groupby('CustomerID')['cohort'].min().reset_index()
cohorts.columns = ['CustomerID', 'transaksi_pertama']
df = df.merge(cohorts, on='CustomerID', how='left')

# %%
cohorts.head()
# Out:
#    CustomerID  transaksi_pertama
# 0     12346.0             197001
# 1     12347.0             197001
# 2     12348.0             197001
# 3     12349.0             197011
# 4     12350.0             197002

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country      Datetime  Month  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  1.291163e+09     12
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  1.291163e+09     12
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
#
#    Year  cohort  transaksi_pertama
# 0  1970  197012           197002.0
# 1  1970  197012           197002.0
# 2  1970  197012           197002.0
# 3  1970  197012           197002.0
# 4  1970  197012           197002.0

# %% [markdown]
# ### Header setiap cohort

# %%
headers = df['cohort'].value_counts().reset_index()
headers.columns = ['Cohorts', 'Count']
headers.head()
# Out:
#    Cohorts  Count
# 0   197011  84711
# 1   197012  68006
# 2   197010  60742
# 3   197009  50226
# 4   197007  39518

# %% [markdown]
# ### Pivot Data

# %%
headers = headers.sort_values(['Cohorts'])['Cohorts'].to_list()
headers
# Out:
# [197001,
#  197002,
#  197003,
#  197004,
#  197005,
#  197006,
#  197007,
#  197008,
#  197009,
#  197010,
#  197011,
#  197012]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country      Datetime  Month  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  1.291163e+09     12
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  1.291163e+09     12
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
#
#    Year  cohort  transaksi_pertama
# 0  1970  197012           197002.0
# 1  1970  197012           197002.0
# 2  1970  197012           197002.0
# 3  1970  197012           197002.0
# 4  1970  197012           197002.0

# %%
df['cohort_distance'] = df.apply(lambda row: (headers.index(row['cohort']) - headers.index(row['transaksi_pertama'])) if (row['transaksi_pertama'] != 0 and row['cohort'] != 0) else np.nan, axis=1)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country      Datetime  Month  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  1.291163e+09     12
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  1.291163e+09     12
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  1.291163e+09     12
#
#    Year  cohort  transaksi_pertama  cohort_distance
# 0  1970  197012           197002.0               10
# 1  1970  197012           197002.0               10
# 2  1970  197012           197002.0               10
# 3  1970  197012           197002.0               10
# 4  1970  197012           197002.0               10

# %%
cohort_pivot = pd.pivot_table(df,
index='transaksi_pertama',
columns='cohort_distance',
values='CustomerID',
aggfunc=pd.Series.nunique)

# %%
cohort_pivot
# Out:
# cohort_distance       0      1      2      3      4      5      6      7   \
# transaksi_pertama
# 197001.0           783.0  299.0  346.0  305.0  359.0  339.0  314.0  311.0
# 197002.0           499.0  144.0  125.0  169.0  158.0  139.0  152.0  169.0
# 197003.0           530.0  109.0  145.0  128.0  123.0  104.0  151.0  131.0
# 197004.0           360.0   90.0   90.0   86.0   78.0   88.0   90.0  105.0
# 197005.0           317.0   73.0   57.0   58.0   73.0   80.0   87.0   67.0
# 197006.0           263.0   56.0   48.0   67.0   63.0   89.0   52.0    NaN
# 197007.0           218.0   45.0   47.0   53.0   58.0   49.0    NaN    NaN
# 197008.0           184.0   47.0   47.0   48.0   40.0    NaN    NaN    NaN
# 197009.0           313.0   93.0  104.0   51.0    NaN    NaN    NaN    NaN
# 197010.0           371.0   99.0   65.0    NaN    NaN    NaN    NaN    NaN
# 197011.0           359.0   81.0    NaN    NaN    NaN    NaN    NaN    NaN
# 197012.0           175.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# cohort_distance       8      9      10     11
# transaksi_pertama
# 197001.0           347.0  340.0  413.0  425.0
# 197002.0           157.0  184.0  154.0    NaN
# 197003.0           165.0  129.0    NaN    NaN
# 197004.0            86.0    NaN    NaN    NaN
# 197005.0             NaN    NaN    NaN    NaN
# 197006.0             NaN    NaN    NaN    NaN
# 197007.0             NaN    NaN    NaN    NaN
# 197008.0             NaN    NaN    NaN    NaN
# 197009.0             NaN    NaN    NaN    NaN
# 197010.0             NaN    NaN    NaN    NaN
# 197011.0             NaN    NaN    NaN    NaN
# 197012.0             NaN    NaN    NaN    NaN

# %%
cohort_pivot = cohort_pivot.div(cohort_pivot[0],axis=0)

# %%
cohort_pivot
# Out:
# cohort_distance     0         1         2         3         4         5   \
# transaksi_pertama
# 197001.0           1.0  0.381865  0.441890  0.389527  0.458493  0.432950
# 197002.0           1.0  0.288577  0.250501  0.338677  0.316633  0.278557
# 197003.0           1.0  0.205660  0.273585  0.241509  0.232075  0.196226
# 197004.0           1.0  0.250000  0.250000  0.238889  0.216667  0.244444
# 197005.0           1.0  0.230284  0.179811  0.182965  0.230284  0.252366
# 197006.0           1.0  0.212928  0.182510  0.254753  0.239544  0.338403
# 197007.0           1.0  0.206422  0.215596  0.243119  0.266055  0.224771
# 197008.0           1.0  0.255435  0.255435  0.260870  0.217391       NaN
# 197009.0           1.0  0.297125  0.332268  0.162939       NaN       NaN
# 197010.0           1.0  0.266846  0.175202       NaN       NaN       NaN
# 197011.0           1.0  0.225627       NaN       NaN       NaN       NaN
# 197012.0           1.0       NaN       NaN       NaN       NaN       NaN
#
# cohort_distance          6         7         8         9         10        11
# transaksi_pertama
# 197001.0           0.401022  0.397190  0.443167  0.434227  0.527458  0.542784
# 197002.0           0.304609  0.338677  0.314629  0.368737  0.308617       NaN
# 197003.0           0.284906  0.247170  0.311321  0.243396       NaN       NaN
# 197004.0           0.250000  0.291667  0.238889       NaN       NaN       NaN
# 197005.0           0.274448  0.211356       NaN       NaN       NaN       NaN
# 197006.0           0.197719       NaN       NaN       NaN       NaN       NaN
# 197007.0                NaN       NaN       NaN       NaN       NaN       NaN
# 197008.0                NaN       NaN       NaN       NaN       NaN       NaN
# 197009.0                NaN       NaN       NaN       NaN       NaN       NaN
# 197010.0                NaN       NaN       NaN       NaN       NaN       NaN
# 197011.0                NaN       NaN       NaN       NaN       NaN       NaN
# 197012.0                NaN       NaN       NaN       NaN       NaN       NaN

# %% [markdown]
# ### Convert to Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.heatmap(cohort_pivot, annot=True, fmt='.0%', mask=cohort_pivot.isnull(), ax=ax, square=True, linewidths=.5, cmap=sns.cubehelix_palette(rot=-.2))
plt.show()
